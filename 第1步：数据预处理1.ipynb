# %%
import pandas as pd
import numpy as np

# %%
# ch= pd.read_csv('房价预测.csv')
path = 'C:\\Users\\ASUS\\Desktop\\IOM魔改2\\IOM209\\房价预测.csv'
try:
    # 将 low_memory 设置为 False
    ch = pd.read_csv(path)
    print("文件读取成功")
except FileNotFoundError:
    print("文件未找到，请检查文件路径。")
except Exception as e:
    print(f"发生其他错误: {e}")
# Out:
# 文件读取成功
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_43308\481588664.py:5: DtypeWarning: Columns (1,11,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   ch = pd.read_csv(path)

# %%
ch
# Out:
#                                                       url              id  \
# 0       https://bj.lianjia.com/chengjiao/101084782030....  101085000000.0
# 1       https://bj.lianjia.com/chengjiao/101086012217....  101086000000.0
# 2       https://bj.lianjia.com/chengjiao/101086041636....  101086000000.0
# 3       https://bj.lianjia.com/chengjiao/101086406841....  101086000000.0
# 4       https://bj.lianjia.com/chengjiao/101086920653....  101087000000.0
# ...                                                   ...             ...
# 318846  https://bj.lianjia.com/chengjiao/BJYZ92311192....    BJYZ92311192
# 318847  https://bj.lianjia.com/chengjiao/BJYZ92320171....    BJYZ92320171
# 318848  https://bj.lianjia.com/chengjiao/BJYZ92324217....    BJYZ92324217
# 318849  https://bj.lianjia.com/chengjiao/BJYZ92333313....    BJYZ92333313
# 318850  https://bj.lianjia.com/chengjiao/BJYZ92363553....    BJYZ92363553
#
#                Lng        Lat           Cid   tradeTime     DOM  followers  \
# ...

# %%
0 in ch['livingRoom'].values
# Out:
# True

# %%
ch[ch['livingRoom'] == 0]
# Out:
#                                                       url              id  \
# 650     https://bj.lianjia.com/chengjiao/101091171721....  101091000000.0
# 5345    https://bj.lianjia.com/chengjiao/101092030915....  101092000000.0
# 43957   https://bj.lianjia.com/chengjiao/101100726068....  101101000000.0
# 186235  https://bj.lianjia.com/chengjiao/BJCY91460122....    BJCY91460122
# 277232  https://bj.lianjia.com/chengjiao/BJSY00467972....    BJSY00467972
# 277465  https://bj.lianjia.com/chengjiao/BJSY84239565....    BJSY84239565
# 278836  https://bj.lianjia.com/chengjiao/BJSY85377576....    BJSY85377576
# 282368  https://bj.lianjia.com/chengjiao/BJSY90096562....    BJSY90096562
# 295643  https://bj.lianjia.com/chengjiao/BJXC84231956....    BJXC84231956
# 316227  https://bj.lianjia.com/chengjiao/BJXC91753051....    BJXC91753051
# 317685  https://bj.lianjia.com/chengjiao/BJYZ88962939....    BJYZ88962939
#
#                Lng        Lat           Cid   tradeTime    DOM  followers  \
# ...

# %%
(ch['livingRoom'] == 0).sum()
# Out:
# 11

# %%
ch = ch[ch['livingRoom'] != 0]

# %%
(ch['livingRoom'] == 0).sum()
# Out:
# 0

# %%
ch.dtypes
# Out:
# url                     object
# id                      object
# Lng                    float64
# Lat                    float64
# Cid                    float64
# tradeTime               object
# DOM                    float64
# followers                int64
# totalPrice             float64
# price                    int64
# square                 float64
# livingRoom              object
# drawingRoom             object
# kitchen                  int64
# bathRoom                object
# floor                   object
# buildingType           float64
# constructionTime        object
# renovationCondition      int64
# buildingStructure        int64
# ladderRatio            float64
# elevator               float64
# fiveYearsProperty      float64
# subway                 float64
# district                 int64
# communityAverage       float64
# dtype: object

# %%
ch
# Out:
#                                                       url              id  \
# 0       https://bj.lianjia.com/chengjiao/101084782030....  101085000000.0
# 1       https://bj.lianjia.com/chengjiao/101086012217....  101086000000.0
# 2       https://bj.lianjia.com/chengjiao/101086041636....  101086000000.0
# 3       https://bj.lianjia.com/chengjiao/101086406841....  101086000000.0
# 4       https://bj.lianjia.com/chengjiao/101086920653....  101087000000.0
# ...                                                   ...             ...
# 318846  https://bj.lianjia.com/chengjiao/BJYZ92311192....    BJYZ92311192
# 318847  https://bj.lianjia.com/chengjiao/BJYZ92320171....    BJYZ92320171
# 318848  https://bj.lianjia.com/chengjiao/BJYZ92324217....    BJYZ92324217
# 318849  https://bj.lianjia.com/chengjiao/BJYZ92333313....    BJYZ92333313
# 318850  https://bj.lianjia.com/chengjiao/BJYZ92363553....    BJYZ92363553
#
#                Lng        Lat           Cid   tradeTime     DOM  followers  \
# ...

# %%
ch=ch.drop(['url'], axis=1)

# %%
ch
# Out:
#                     id         Lng        Lat           Cid   tradeTime  \
# 0       101085000000.0  116.475489  40.019520  1.111030e+12    2016/8/9
# 1       101086000000.0  116.453917  39.881534  1.111030e+12   2016/7/28
# 2       101086000000.0  116.561978  39.877145  1.111040e+12  2016/12/11
# 3       101086000000.0  116.438010  40.076114  1.111040e+12   2016/9/30
# 4       101087000000.0  116.428392  39.886229  1.111030e+12   2016/8/28
# ...                ...         ...        ...           ...         ...
# 318846    BJYZ92311192  116.546899  39.755236  1.111030e+12   2016/6/10
# 318847    BJYZ92320171  116.497474  39.810115  1.111030e+12   2016/6/10
# 318848    BJYZ92324217  116.497256  39.804081  1.111030e+12    2016/6/5
# 318849    BJYZ92333313  116.501794  39.799347  1.111030e+12   2016/6/12
# 318850    BJYZ92363553  116.497474  39.810115  1.111030e+12   2016/6/11
#
#            DOM  followers  totalPrice  price  square  ... buildingType  \
# ...

# %%
ch.to_csv("删除url版.csv",index=False)

# %%
# 查看缺失值
# TODO为什么不在最开始使用？
ch.isnull().sum()
# Out:
# id                          0
# Lng                         0
# Lat                         0
# Cid                         0
# tradeTime                   0
# DOM                    157972
# followers                   0
# totalPrice                  0
# price                       0
# square                      0
# livingRoom                  0
# drawingRoom                 0
# kitchen                     0
# bathRoom                    0
# floor                       0
# buildingType             2020
# constructionTime            0
# renovationCondition         0
# buildingStructure           0
# ladderRatio                 0
# elevator                   32
# fiveYearsProperty          32
# subway                     32
# district                    0
# communityAverage          463
# dtype: int64

# %%
#发现DOM缺失值过多，因此应该删除，此外发现不仅是url无用，id与cid也对该数据预测无用，因此同时删除

# %%
ch.drop(['DOM','Cid','id'],axis=1,inplace=True)

# %%
#获取初步数据

# %%
ch.to_csv("初步数据版.csv",index=False)
